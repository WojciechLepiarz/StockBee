# %% [markdown]
# # Analysis of how stocks changed price in the past (in a given year, half of the year or a quarter)
# ## I want to know ho big are price movements in given timeframes observed in the past

# %%
import glob
import pandas as pd
import numpy as np
from stockbee.stock_lists import gpw, nc

import pandas_bokeh
pandas_bokeh.output_notebook()
pd.set_option('plotting.backend', 'pandas_bokeh')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Program outline:
# - Plot the price change data on a histogram: year, half-year, quarter, week, day (5 plots).
#     - Beside all time plot, split the plots into ten-year periods (90s, 2000s, 2010s)
# - Count some interesting metrics:
#     - Average and median price change in a year / half-year / quarter....
#     - ?

# %%
def getPriceChangeData(path: str, periods: list) -> tuple:
    sourceDataFrame = pd.read_csv(path, index_col=1)
    sourceDataFrame.index = pd.to_datetime(sourceDataFrame.index, format="%Y%m%d")
    labels = [f'Diff%_{str(period)}' for period in periods]
    for period in periods:
        sourceDataFrame[f'Diff%_{str(period)}'] = (sourceDataFrame['<CLOSE>'] / sourceDataFrame['<CLOSE>'].shift(period) - 1)*100 
    return sourceDataFrame[labels].dropna(how='any').reset_index(drop=True)

periods = [1, 5, 20, 60, 125, 255]
labels = [f'Diff%_{str(period)}' for period in periods]
data = pd.DataFrame([], columns=labels)
for symbol in ['..\\data\\DAX_corrected.mst']:
    data = data.append(getPriceChangeData(symbol, periods), ignore_index = True)
data
# Out:
#        Diff%_1   Diff%_5   Diff%_20  Diff%_60  Diff%_125  Diff%_255
# 0    -0.360221  3.087981   2.483239  8.306531   5.522503  11.733590
# 1     1.127609  2.836010   3.826610  8.878180   6.848256  13.249470
# 2    -0.489424  0.386399   3.117971  6.436635   5.590679  12.831154
# 3    -0.372081  0.223723   2.494720  6.301907   6.618152  12.945455
# 4     1.159047  1.054934   2.912918  7.064970   7.133115  14.732947
# ...        ...       ...        ...       ...        ...        ...
# 6299 -0.078251 -0.088594   7.799753  1.402740  13.291965  -0.712118
# 6300  1.260535  1.210419  10.186620  2.452473  10.574248   1.020661
# 6301 -0.019861  0.665890  14.958596  0.350136   6.426018   1.157737
# 6302 -0.024304  1.531465  14.558457  1.752213   6.886335   0.932020
# 6303  0.369621  1.510438  15.395691  3.838924   3.798351   0.673614
#
# [6304 rows x 6 columns]

# %%
data['Diff%_1'].plot.hist(bins=20)
# Out:
#   <div class="bk-root" id="435dd2e7-dce9-4b7f-847c-e9e0cfabd79c" data-root-id="2136"></div>
# Figure(id='2136', ...)

# %%
data['Diff%_1'].size
# Out:
# 6304

# %%
sourceDataFrame = pd.read_csv('..\\data\\DAX_corrected.mst', index_col=1)
sourceDataFrame['<CLOSE>'].idxmin()
# Out:
# 19950328

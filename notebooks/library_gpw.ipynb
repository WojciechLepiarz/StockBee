# %%
gpw = ['..\\data\\11BIT.mst',
 '..\\data\\ABPL.mst',
 '..\\data\\ACAUTOGAZ.mst',
 '..\\data\\AGORA.mst',
 '..\\data\\ALIOR.mst',
 '..\\data\\ALUMETAL.mst',
 '..\\data\\AMBRA.mst',
 '..\\data\\AMICA.mst',
 '..\\data\\AMREST.mst',
 '..\\data\\APATOR.mst',
 '..\\data\\ARCHICOM.mst',
 '..\\data\\ARCTIC.mst',
 '..\\data\\ASBIS.mst',
 '..\\data\\ASSECOBS.mst',
 '..\\data\\ASSECOPOL.mst',
 '..\\data\\ASSECOSEE.mst',
 '..\\data\\ASTARTA.mst',
 '..\\data\\ATAL.mst',
 '..\\data\\ATMGRUPA.mst',
 '..\\data\\AUTOPARTN.mst',
 '..\\data\\BAHOLDING.mst',
 '..\\data\\BENEFIT.mst',
 '..\\data\\BIOTON.mst',
 '..\\data\\BNPPPL.mst',
 '..\\data\\BOGDANKA.mst',
 '..\\data\\BOOMBIT.mst',
 '..\\data\\BORYSZEW.mst',
 '..\\data\\BOS.mst',
 '..\\data\\BUDIMEX.mst',
 '..\\data\\CCC.mst',
 '..\\data\\CDPROJEKT.mst',
 '..\\data\\CIECH.mst',
 '..\\data\\CIGAMES.mst',
 '..\\data\\CLNPHARMA.mst',
 '..\\data\\COMARCH.mst',
 '..\\data\\COMP.mst',
 '..\\data\\CPGROUP.mst',
 '..\\data\\CYFRPLSAT.mst',
 '..\\data\\DATAWALK.mst',
 '..\\data\\DEBICA.mst',
 '..\\data\\DEVELIA.mst',
 '..\\data\\DINOPL.mst',
 '..\\data\\DOMDEV.mst',
 '..\\data\\ECHO.mst',
 '..\\data\\EKOEXPORT.mst',
 '..\\data\\ELEMENTAL.mst',
 '..\\data\\EMCINSMED.mst',
 '..\\data\\ENEA.mst',
 '..\\data\\ENERGA.mst',
 '..\\data\\ENTER.mst',
 '..\\data\\EUROCASH.mst',
 '..\\data\\FAMUR.mst',
 '..\\data\\FERRO.mst',
 '..\\data\\FORTE.mst',
 '..\\data\\GETIN.mst',
 '..\\data\\GPW.mst',
 '..\\data\\GRUPAAZOTY.mst',
 '..\\data\\GTC.mst',
 '..\\data\\HANDLOWY.mst',
 '..\\data\\IDEABANK.mst',
 '..\\data\\IMCOMPANY.mst',
 '..\\data\\INGBSK.mst',
 '..\\data\\INSTALKRK.mst',
 '..\\data\\INTERAOLT.mst',
 '..\\data\\INTERCARS.mst',
 '..\\data\\JSW.mst',
 '..\\data\\KERNEL.mst',
 '..\\data\\KETY.mst',
 '..\\data\\KGHM.mst',
 '..\\data\\KOGENERA.mst',
 '..\\data\\KRUK.mst',
 '..\\data\\LENTEX.mst',
 '..\\data\\LIVECHAT.mst',
 '..\\data\\LOTOS.mst',
 '..\\data\\LPP.mst',
 '..\\data\\MABION.mst',
 '..\\data\\MANGATA.mst',
 '..\\data\\MBANK.mst',
 '..\\data\\MCI.mst',
 '..\\data\\MEDICALG.mst',
 '..\\data\\MENNICA.mst',
 '..\\data\\MERCATOR.mst',
 '..\\data\\MILLENNIUM.mst',
 '..\\data\\MIRBUD.mst',
 '..\\data\\MLPGROUP.mst',
 '..\\data\\MLSYSTEM.mst',
 '..\\data\\NETIA.mst',
 '..\\data\\NEUCA.mst',
 '..\\data\\NEWAG.mst',
 '..\\data\\OAT.mst',
 '..\\data\\OPONEO.PL.mst',
 '..\\data\\ORANGEPL.mst',
 '..\\data\\OVOSTAR.mst',
 '..\\data\\PBKM.mst',
 '..\\data\\PCCROKITA.mst',
 '..\\data\\PEKABEX.mst',
 '..\\data\\PEKAO.mst',
 '..\\data\\PEP.mst',
 '..\\data\\PGE.mst',
 '..\\data\\PGNIG.mst',
 '..\\data\\PGSSOFT.mst',
 '..\\data\\PHN.mst',
 '..\\data\\PKNORLEN.mst',
 '..\\data\\PKOBP.mst',
 '..\\data\\PKPCARGO.mst',
 '..\\data\\PLAY.mst',
 '..\\data\\PLAYWAY.mst',
 '..\\data\\POLICE.mst',
 '..\\data\\POLIMEXMS.mst',
 '..\\data\\PRAIRIE.mst',
 '..\\data\\PZU.mst',
 '..\\data\\QUERCUS.mst',
 '..\\data\\R22.mst',
 '..\\data\\RAFAKO.mst',
 '..\\data\\RAINBOW.mst',
 '..\\data\\RYVU.mst',
 '..\\data\\SANOK.mst',
 '..\\data\\SANPL.mst',
 '..\\data\\SELVITA.mst',
 '..\\data\\SERINUS.mst',
 '..\\data\\SNIEZKA.mst',
 '..\\data\\STALEXP.mst',
 '..\\data\\STALPROD.mst',
 '..\\data\\TAURONPE.mst',
 '..\\data\\TIM.mst',
 '..\\data\\TORPOL.mst',
 '..\\data\\TOYA.mst',
 '..\\data\\TRAKCJA.mst',
 '..\\data\\TSGAMES.mst',
 '..\\data\\ULTGAMES.mst',
 '..\\data\\UNIBEP.mst',
 '..\\data\\UNIMOT.mst',
 '..\\data\\VIGOSYS.mst',
 '..\\data\\VOTUM.mst',
 '..\\data\\VOXEL.mst',
 '..\\data\\VRG.mst',
 '..\\data\\WAWEL.mst',
 '..\\data\\WIELTON.mst',
 '..\\data\\WIRTUALNA.mst',
 '..\\data\\ZEPAK.mst',
 '..\\data\\HURTIMEX.mst',
 '..\\data\\ICPGROUP.mst',
 '..\\data\\MENNICASK.mst']
